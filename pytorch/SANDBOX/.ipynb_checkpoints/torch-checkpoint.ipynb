# %%
from d2l import torch

X = torch.arange(3).reshape(3)

# %%
Y = torch.arange(3, 6)
Y
# Out:
# tensor([3, 4, 5])

# %%
X + Y
# Out:
# tensor([3, 5, 7])

# %%
X[:] = X + Y
Z = X <= Y

# %%
Z
# Out:
# tensor([False, False, False])

# %%
X[2] = 40

# %%
X
# Out:
# tensor([27, 37, 75])

# %%
torch.exp(X)
# Out:
# tensor([5.3205e+11, 1.1719e+16, 3.7332e+32])
